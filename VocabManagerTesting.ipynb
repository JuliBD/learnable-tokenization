# %%
import pandas as pd
from vocab_manager import VocabManager

starting_vocab = [(i,) for i in range(257)]

vocab_manager = VocabManager(starting_vocab)

# %%
vocab_manager.id2idx((200,50))
# Out:
# 259

# %%
from transformers.modeling_outputs import CausalLMOutput

# %%
vocab_manager.vocab
# Out:
#       token_id
# 0         (0,)
# 1         (1,)
# 2         (2,)
# 3         (3,)
# 4         (4,)
# ..         ...
# 254     (254,)
# 255     (255,)
# 256     (256,)
# 258     (300,)
# 259  (200, 50)
#
# [259 rows x 1 columns]

# %%
from torch import nn
nn.Linear(in_features=50, out_features= 80).out_features
# Out:
# 80

# %%
from torch import Tensor
